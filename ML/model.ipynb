# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import random
from sklearn.metrics import roc_auc_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
user_df = pd.read_csv("./data/user.csv")
rating_df = pd.read_csv("./data/tourism_rating.csv")
place_df = pd.read_csv("./data/tourism_with_id.csv", usecols=["Place_Id", "Place_Name", "City", "Rating"])

# %%
user_df = user_df.rename(columns={"User_Id": "user_id", "Location": "location", "Age": "age"})
place_df = place_df.rename(columns={"Place_Id": "place_id", "Place_Name": "place_name", "City": "city", "Rating": "rating"})
rating_df = rating_df.rename(columns={"User_Id": "user_id", "Place_Id": "place_id", "Place_Ratings": "place_rating"})

# %%
# print(user_df.describe(), "\n")
# print(user_df.isnull().sum(), "\n")
# print(user_df[user_df.duplicated(keep=False)], "\n")

# print(rating_df.describe(), "\n")
# print(rating_df.isnull().sum(), "\n")
# print(rating_df[rating_df.duplicated(keep=False)], "\n")
user_df = user_df.drop_duplicates(subset=["user_id"], keep="last")
place_df = place_df.drop_duplicates(subset=["place_id"], keep="last")
rating_df = rating_df.drop_duplicates(subset=["user_id", "place_id"], keep="last")


# print(place_df.describe(), "\n")
# print(place_df.isnull().sum(), "\n")
# print(place_df[place_df.duplicated(keep=False)], "\n")

# %%
# Converting rating to interaction bool. (Explicit to Implicit)
rating_df["implicit_label"] = (rating_df["place_rating"] >= 4).astype(int)

popular_places = (
    rating_df['place_id']
    .value_counts()
    .sort_values(ascending=False)
    .head(10) 
    .index
    .tolist()
)

default_user_id = 301
default_rating = 5

new_user_data = pd.DataFrame({
    'user_id': [default_user_id] * len(popular_places),
    'place_id': popular_places,
    'place_rating': [default_rating] * len(popular_places),
    'implicit_label': [1] * len(popular_places)  # or 0 if you want to distinguish
})

rating_df = pd.concat([rating_df, new_user_data], ignore_index=True)

rating_df["user_id"] = rating_df["user_id"] - 1
rating_df["place_id"] = rating_df["place_id"] - 1

user_df["user_id"] = user_df["user_id"] - 1
place_df["place_id"] = rating_df["place_id"] - 1

user_len = rating_df["user_id"].max() + 1
place_len = rating_df["place_id"].max() + 1
# rating_df
print(place_len)
print(user_len)
# Out:
# 437
# 301

# %%
# rating_df[rating_df['implicit_label'] == 1].groupby('user_id')['place_id'].apply(set).to_dict()
# rating_df
# rating_df[rating_df['implicit_label'] == 1].describe()
print(rating_df.to_json(orient='records', indent=4))
# Out:
# [
#     {
#         "user_id":1,
#         "place_id":179,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":344,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":5,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":373,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":101,
#         "place_rating":4
#     },
#     {
#         "user_id":1,
#         "place_id":312,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":258,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":20,
#         "place_rating":4
#     },
#     {
#         "user_id":1,
#         "place_id":154,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":393,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":103,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":208,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":89,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":405,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":41,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":336,
#         "place_rating":4
#     },
#     {
#         "user_id":1,
#         "place_id":67,
#         "place_rating":4
#     },
#     {
#         "user_id":1,
#         "place_id":292,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":222,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":76,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":428,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":15,
#         "place_rating":3
#     },
#     {
#         "user_id":1,
#         "place_id":246,
#         "place_rating":4
#     },
#     {
#         "user_id":1,
#         "place_id":265,
#         "place_rating":5
#     },
#     {
#         "user_id":1,
#         "place_id":21,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":328,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":307,
#         "place_rating":4
#     },
#     {
#         "user_id":1,
#         "place_id":302,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":48,
#         "place_rating":2
#     },
#     {
#         "user_id":1,
#         "place_id":328,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":147,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":2,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":322,
#         "place_rating":4
#     },
#     {
#         "user_id":2,
#         "place_id":23,
#         "place_rating":3
#     },
#     {
#         "user_id":2,
#         "place_id":85,
#         "place_rating":4
#     },
#     {
#         "user_id":2,
#         "place_id":371,
#         "place_rating":3
#     },
#     {
#         "user_id":2,
#         "place_id":78,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":111,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":107,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":185,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":413,
#         "place_rating":3
#     },
#     {
#         "user_id":2,
#         "place_id":389,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":437,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":105,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":176,
#         "place_rating":3
#     },
#     {
#         "user_id":2,
#         "place_id":407,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":208,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":437,
#         "place_rating":4
#     },
#     {
#         "user_id":2,
#         "place_id":208,
#         "place_rating":3
#     },
#     {
#         "user_id":2,
#         "place_id":281,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":167,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":384,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":426,
#         "place_rating":4
#     },
#     {
#         "user_id":2,
#         "place_id":390,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":367,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":166,
#         "place_rating":2
#     },
#     {
#         "user_id":2,
#         "place_id":18,
#         "place_rating":5
#     },
#     {
#         "user_id":2,
#         "place_id":321,
#         "place_rating":3
#     },
#     {
#         "user_id":2,
#         "place_id":262,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":223,
#         "place_rating":5
#     },
#     {
#         "user_id":3,
#         "place_id":17,
#         "place_rating":5
#     },
#     {
#         "user_id":3,
#         "place_id":319,
#         "place_rating":5
#     },
#     {
#         "user_id":3,
#         "place_id":310,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":421,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":202,
#         "place_rating":5
#     },
#     {
#         "user_id":3,
#         "place_id":48,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":283,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":202,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":250,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":118,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":54,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":70,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":33,
#         "place_rating":4
#     },
#     {
#         "user_id":3,
#         "place_id":227,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":86,
#         "place_rating":4
#     },
#     {
#         "user_id":3,
#         "place_id":105,
#         "place_rating":5
#     },
#     {
#         "user_id":3,
#         "place_id":249,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":131,
#         "place_rating":4
#     },
#     {
#         "user_id":3,
#         "place_id":382,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":193,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":176,
#         "place_rating":2
#     },
#     {
#         "user_id":3,
#         "place_id":104,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":24,
#         "place_rating":4
#     },
#     {
#         "user_id":3,
#         "place_id":128,
#         "place_rating":5
#     },
#     {
#         "user_id":3,
#         "place_id":134,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":228,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":237,
#         "place_rating":3
#     },
#     {
#         "user_id":3,
#         "place_id":100,
#         "place_rating":4
#     },
#     {
#         "user_id":3,
#         "place_id":198,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":50,
#         "place_rating":2
#     },
#     {
#         "user_id":4,
#         "place_id":376,
#         "place_rating":2
#     },
#     {
#         "user_id":4,
#         "place_id":268,
#         "place_rating":4
#     },
#     {
#         "user_id":4,
#         "place_id":242,
#         "place_rating":4
#     },
#     {
#         "user_id":4,
#         "place_id":82,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":348,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":409,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":88,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":4,
#         "place_rating":4
#     },
#     {
#         "user_id":4,
#         "place_id":377,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":43,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":15,
#         "place_rating":4
#     },
#     {
#         "user_id":4,
#         "place_id":91,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":193,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":312,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":44,
#         "place_rating":2
#     },
#     {
#         "user_id":4,
#         "place_id":14,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":406,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":383,
#         "place_rating":2
#     },
#     {
#         "user_id":4,
#         "place_id":229,
#         "place_rating":2
#     },
#     {
#         "user_id":4,
#         "place_id":290,
#         "place_rating":3
#     },
#     {
#         "user_id":4,
#         "place_id":5,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":294,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":309,
#         "place_rating":5
#     },
#     {
#         "user_id":4,
#         "place_id":74,
#         "place_rating":2
#     },
#     {
#         "user_id":4,
#         "place_id":97,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":421,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":138,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":436,
#         "place_rating":5
#     },
#     {
#         "user_id":5,
#         "place_id":395,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":300,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":321,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":68,
#         "place_rating":5
#     },
#     {
#         "user_id":5,
#         "place_id":55,
#         "place_rating":5
#     },
#     {
#         "user_id":5,
#         "place_id":434,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":9,
#         "place_rating":5
#     },
#     {
#         "user_id":5,
#         "place_id":166,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":151,
#         "place_rating":5
#     },
#     {
#         "user_id":5,
#         "place_id":4,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":61,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":321,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":159,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":397,
#         "place_rating":5
#     },
#     {
#         "user_id":5,
#         "place_id":391,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":407,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":301,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":143,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":27,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":283,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":190,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":346,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":67,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":381,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":368,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":433,
#         "place_rating":4
#     },
#     {
#         "user_id":5,
#         "place_id":301,
#         "place_rating":2
#     },
#     {
#         "user_id":5,
#         "place_id":420,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":335,
#         "place_rating":3
#     },
#     {
#         "user_id":5,
#         "place_id":115,
#         "place_rating":3
#     },
#     {
#         "user_id":6,
#         "place_id":433,
#         "place_rating":4
#     },
#     {
#         "user_id":6,
#         "place_id":334,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":348,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":219,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":178,
#         "place_rating":3
#     },
#     {
#         "user_id":6,
#         "place_id":266,
#         "place_rating":3
#     },
#     {
#         "user_id":6,
#         "place_id":92,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":64,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":102,
#         "place_rating":4
#     },
#     {
#         "user_id":6,
#         "place_id":166,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":257,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":243,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":346,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":116,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":359,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":121,
#         "place_rating":4
#     },
#     {
#         "user_id":6,
#         "place_id":385,
#         "place_rating":4
#     },
#     {
#         "user_id":6,
#         "place_id":398,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":64,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":88,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":119,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":393,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":4,
#         "place_rating":4
#     },
#     {
#         "user_id":6,
#         "place_id":298,
#         "place_rating":3
#     },
#     {
#         "user_id":6,
#         "place_id":410,
#         "place_rating":2
#     },
#     {
#         "user_id":6,
#         "place_id":224,
#         "place_rating":5
#     },
#     {
#         "user_id":6,
#         "place_id":379,
#         "place_rating":4
#     },
#     {
#         "user_id":6,
#         "place_id":382,
#         "place_rating":2
#     },
#     {
#         "user_id":7,
#         "place_id":255,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":269,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":213,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":228,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":126,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":192,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":376,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":183,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":129,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":303,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":296,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":213,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":237,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":99,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":88,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":148,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":13,
#         "place_rating":2
#     },
#     {
#         "user_id":7,
#         "place_id":377,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":183,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":247,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":31,
#         "place_rating":3
#     },
#     {
#         "user_id":7,
#         "place_id":298,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":290,
#         "place_rating":4
#     },
#     {
#         "user_id":7,
#         "place_id":385,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":77,
#         "place_rating":5
#     },
#     {
#         "user_id":7,
#         "place_id":107,
#         "place_rating":2
#     },
#     {
#         "user_id":7,
#         "place_id":77,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":158,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":301,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":290,
#         "place_rating":2
#     },
#     {
#         "user_id":8,
#         "place_id":322,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":306,
#         "place_rating":4
#     },
#     {
#         "user_id":8,
#         "place_id":98,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":235,
#         "place_rating":4
#     },
#     {
#         "user_id":8,
#         "place_id":45,
#         "place_rating":2
#     },
#     {
#         "user_id":8,
#         "place_id":173,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":306,
#         "place_rating":2
#     },
#     {
#         "user_id":8,
#         "place_id":393,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":395,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":89,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":433,
#         "place_rating":4
#     },
#     {
#         "user_id":8,
#         "place_id":143,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":275,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":25,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":98,
#         "place_rating":2
#     },
#     {
#         "user_id":8,
#         "place_id":130,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":223,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":368,
#         "place_rating":2
#     },
#     {
#         "user_id":8,
#         "place_id":164,
#         "place_rating":5
#     },
#     {
#         "user_id":8,
#         "place_id":267,
#         "place_rating":4
#     },
#     {
#         "user_id":8,
#         "place_id":202,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":56,
#         "place_rating":2
#     },
#     {
#         "user_id":8,
#         "place_id":30,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":238,
#         "place_rating":3
#     },
#     {
#         "user_id":8,
#         "place_id":294,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":402,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":196,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":406,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":55,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":30,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":246,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":402,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":30,
#         "place_rating":2
#     },
#     {
#         "user_id":9,
#         "place_id":310,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":417,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":304,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":206,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":211,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":28,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":264,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":242,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":403,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":253,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":265,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":331,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":188,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":54,
#         "place_rating":3
#     },
#     {
#         "user_id":9,
#         "place_id":420,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":416,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":378,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":233,
#         "place_rating":4
#     },
#     {
#         "user_id":9,
#         "place_id":95,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":105,
#         "place_rating":2
#     },
#     {
#         "user_id":9,
#         "place_id":233,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":204,
#         "place_rating":2
#     },
#     {
#         "user_id":9,
#         "place_id":225,
#         "place_rating":5
#     },
#     {
#         "user_id":9,
#         "place_id":204,
#         "place_rating":2
#     },
#     {
#         "user_id":9,
#         "place_id":341,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":145,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":36,
#         "place_rating":4
#     },
#     {
#         "user_id":10,
#         "place_id":168,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":12,
#         "place_rating":2
#     },
#     {
#         "user_id":10,
#         "place_id":134,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":280,
#         "place_rating":4
#     },
#     {
#         "user_id":10,
#         "place_id":236,
#         "place_rating":4
#     },
#     {
#         "user_id":10,
#         "place_id":95,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":344,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":18,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":42,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":90,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":280,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":75,
#         "place_rating":4
#     },
#     {
#         "user_id":10,
#         "place_id":63,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":205,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":268,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":234,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":284,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":405,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":230,
#         "place_rating":4
#     },
#     {
#         "user_id":10,
#         "place_id":197,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":339,
#         "place_rating":3
#     },
#     {
#         "user_id":10,
#         "place_id":159,
#         "place_rating":2
#     },
#     {
#         "user_id":10,
#         "place_id":77,
#         "place_rating":2
#     },
#     {
#         "user_id":10,
#         "place_id":23,
#         "place_rating":2
#     },
#     {
#         "user_id":10,
#         "place_id":67,
#         "place_rating":5
#     },
#     {
#         "user_id":10,
#         "place_id":35,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":229,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":226,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":310,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":430,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":107,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":37,
#         "place_rating":5
#     },
#     {
#         "user_id":11,
#         "place_id":322,
#         "place_rating":5
#     },
#     {
#         "user_id":11,
#         "place_id":109,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":341,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":206,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":97,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":41,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":355,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":82,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":376,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":406,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":186,
#         "place_rating":4
#     },
#     {
#         "user_id":11,
#         "place_id":88,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":378,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":151,
#         "place_rating":5
#     },
#     {
#         "user_id":11,
#         "place_id":149,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":6,
#         "place_rating":5
#     },
#     {
#         "user_id":11,
#         "place_id":150,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":11,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":127,
#         "place_rating":3
#     },
#     {
#         "user_id":11,
#         "place_id":6,
#         "place_rating":2
#     },
#     {
#         "user_id":11,
#         "place_id":5,
#         "place_rating":5
#     },
#     {
#         "user_id":11,
#         "place_id":236,
#         "place_rating":2
#     },
#     {
#         "user_id":12,
#         "place_id":429,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":194,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":27,
#         "place_rating":2
#     },
#     {
#         "user_id":12,
#         "place_id":236,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":49,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":369,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":94,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":226,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":274,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":72,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":183,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":265,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":301,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":46,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":65,
#         "place_rating":2
#     },
#     {
#         "user_id":12,
#         "place_id":203,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":379,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":139,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":5,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":141,
#         "place_rating":2
#     },
#     {
#         "user_id":12,
#         "place_id":312,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":154,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":71,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":302,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":75,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":30,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":52,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":27,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":102,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":128,
#         "place_rating":2
#     },
#     {
#         "user_id":12,
#         "place_id":293,
#         "place_rating":5
#     },
#     {
#         "user_id":12,
#         "place_id":82,
#         "place_rating":4
#     },
#     {
#         "user_id":12,
#         "place_id":402,
#         "place_rating":3
#     },
#     {
#         "user_id":12,
#         "place_id":98,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":398,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":65,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":398,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":371,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":422,
#         "place_rating":4
#     },
#     {
#         "user_id":13,
#         "place_id":214,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":20,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":114,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":229,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":56,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":265,
#         "place_rating":4
#     },
#     {
#         "user_id":13,
#         "place_id":129,
#         "place_rating":4
#     },
#     {
#         "user_id":13,
#         "place_id":75,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":296,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":191,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":156,
#         "place_rating":3
#     },
#     {
#         "user_id":13,
#         "place_id":177,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":437,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":406,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":290,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":163,
#         "place_rating":4
#     },
#     {
#         "user_id":13,
#         "place_id":242,
#         "place_rating":3
#     },
#     {
#         "user_id":13,
#         "place_id":178,
#         "place_rating":2
#     },
#     {
#         "user_id":13,
#         "place_id":142,
#         "place_rating":5
#     },
#     {
#         "user_id":13,
#         "place_id":245,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":67,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":325,
#         "place_rating":3
#     },
#     {
#         "user_id":14,
#         "place_id":422,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":88,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":118,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":344,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":227,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":259,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":376,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":368,
#         "place_rating":3
#     },
#     {
#         "user_id":14,
#         "place_id":396,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":167,
#         "place_rating":3
#     },
#     {
#         "user_id":14,
#         "place_id":11,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":230,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":54,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":304,
#         "place_rating":3
#     },
#     {
#         "user_id":14,
#         "place_id":249,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":96,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":50,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":8,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":233,
#         "place_rating":3
#     },
#     {
#         "user_id":14,
#         "place_id":362,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":173,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":435,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":167,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":294,
#         "place_rating":2
#     },
#     {
#         "user_id":14,
#         "place_id":59,
#         "place_rating":3
#     },
#     {
#         "user_id":14,
#         "place_id":274,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":186,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":91,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":328,
#         "place_rating":5
#     },
#     {
#         "user_id":14,
#         "place_id":371,
#         "place_rating":4
#     },
#     {
#         "user_id":14,
#         "place_id":171,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":298,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":277,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":90,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":342,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":435,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":348,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":23,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":365,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":340,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":260,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":369,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":187,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":74,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":297,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":21,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":95,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":367,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":207,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":284,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":321,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":248,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":153,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":248,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":355,
#         "place_rating":5
#     },
#     {
#         "user_id":15,
#         "place_id":27,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":239,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":434,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":9,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":360,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":275,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":142,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":119,
#         "place_rating":4
#     },
#     {
#         "user_id":15,
#         "place_id":219,
#         "place_rating":2
#     },
#     {
#         "user_id":15,
#         "place_id":417,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":170,
#         "place_rating":3
#     },
#     {
#         "user_id":15,
#         "place_id":357,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":264,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":68,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":292,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":89,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":203,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":73,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":201,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":252,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":434,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":275,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":150,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":414,
#         "place_rating":5
#     },
#     {
#         "user_id":16,
#         "place_id":67,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":385,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":359,
#         "place_rating":5
#     },
#     {
#         "user_id":16,
#         "place_id":266,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":30,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":390,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":322,
#         "place_rating":5
#     },
#     {
#         "user_id":16,
#         "place_id":413,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":121,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":237,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":384,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":132,
#         "place_rating":5
#     },
#     {
#         "user_id":16,
#         "place_id":26,
#         "place_rating":2
#     },
#     {
#         "user_id":16,
#         "place_id":347,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":121,
#         "place_rating":4
#     },
#     {
#         "user_id":16,
#         "place_id":167,
#         "place_rating":3
#     },
#     {
#         "user_id":16,
#         "place_id":270,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":16,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":339,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":406,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":267,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":384,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":371,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":19,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":318,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":104,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":37,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":256,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":11,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":134,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":181,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":236,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":98,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":199,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":410,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":33,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":237,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":265,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":78,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":154,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":173,
#         "place_rating":5
#     },
#     {
#         "user_id":17,
#         "place_id":414,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":288,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":330,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":3,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":47,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":2,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":145,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":27,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":32,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":70,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":308,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":210,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":92,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":398,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":279,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":398,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":321,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":262,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":307,
#         "place_rating":3
#     },
#     {
#         "user_id":17,
#         "place_id":289,
#         "place_rating":4
#     },
#     {
#         "user_id":17,
#         "place_id":346,
#         "place_rating":2
#     },
#     {
#         "user_id":17,
#         "place_id":371,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":102,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":332,
#         "place_rating":2
#     },
#     {
#         "user_id":18,
#         "place_id":80,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":49,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":375,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":71,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":182,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":54,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":176,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":197,
#         "place_rating":2
#     },
#     {
#         "user_id":18,
#         "place_id":151,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":260,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":405,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":8,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":88,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":50,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":412,
#         "place_rating":2
#     },
#     {
#         "user_id":18,
#         "place_id":147,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":101,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":357,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":272,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":413,
#         "place_rating":2
#     },
#     {
#         "user_id":18,
#         "place_id":185,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":80,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":426,
#         "place_rating":2
#     },
#     {
#         "user_id":18,
#         "place_id":245,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":46,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":184,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":201,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":113,
#         "place_rating":2
#     },
#     {
#         "user_id":18,
#         "place_id":111,
#         "place_rating":4
#     },
#     {
#         "user_id":18,
#         "place_id":399,
#         "place_rating":3
#     },
#     {
#         "user_id":18,
#         "place_id":235,
#         "place_rating":5
#     },
#     {
#         "user_id":18,
#         "place_id":261,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":194,
#         "place_rating":5
#     },
#     {
#         "user_id":19,
#         "place_id":228,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":417,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
#         "place_id":205,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
#         "place_id":112,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
#         "place_id":42,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":168,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
#         "place_id":327,
#         "place_rating":4
#     },
#     {
#         "user_id":19,
#         "place_id":395,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":418,
#         "place_rating":4
#     },
#     {
#         "user_id":19,
#         "place_id":84,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":400,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":195,
#         "place_rating":4
#     },
#     {
#         "user_id":19,
#         "place_id":34,
#         "place_rating":5
#     },
#     {
#         "user_id":19,
#         "place_id":295,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
#         "place_id":247,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
#         "place_id":344,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":203,
#         "place_rating":2
#     },
#     {
#         "user_id":19,
#         "place_id":56,
#         "place_rating":3
#     },
#     {
#         "user_id":19,
# ...
#         "place_id":128,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":73,
#         "place_rating":4
#     },
#     {
#         "user_id":295,
#         "place_id":422,
#         "place_rating":5
#     },
#     {
#         "user_id":295,
#         "place_id":403,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":42,
#         "place_rating":3
#     },
#     {
#         "user_id":295,
#         "place_id":406,
#         "place_rating":3
#     },
#     {
#         "user_id":295,
#         "place_id":107,
#         "place_rating":5
#     },
#     {
#         "user_id":295,
#         "place_id":197,
#         "place_rating":2
#     },
#     {
#         "user_id":295,
#         "place_id":255,
#         "place_rating":3
#     },
#     {
#         "user_id":295,
#         "place_id":130,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":296,
#         "place_rating":4
#     },
#     {
#         "user_id":295,
#         "place_id":110,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":2,
#         "place_rating":2
#     },
#     {
#         "user_id":295,
#         "place_id":145,
#         "place_rating":5
#     },
#     {
#         "user_id":295,
#         "place_id":89,
#         "place_rating":3
#     },
#     {
#         "user_id":295,
#         "place_id":266,
#         "place_rating":5
#     },
#     {
#         "user_id":295,
#         "place_id":163,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":277,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":3,
#         "place_rating":1
#     },
#     {
#         "user_id":295,
#         "place_id":27,
#         "place_rating":5
#     },
#     {
#         "user_id":295,
#         "place_id":99,
#         "place_rating":3
#     },
#     {
#         "user_id":295,
#         "place_id":160,
#         "place_rating":5
#     },
#     {
#         "user_id":296,
#         "place_id":389,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":71,
#         "place_rating":1
#     },
#     {
#         "user_id":296,
#         "place_id":297,
#         "place_rating":3
#     },
#     {
#         "user_id":296,
#         "place_id":314,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":6,
#         "place_rating":5
#     },
#     {
#         "user_id":296,
#         "place_id":224,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":406,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":6,
#         "place_rating":3
#     },
#     {
#         "user_id":296,
#         "place_id":177,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":13,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":276,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":213,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":18,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":240,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":118,
#         "place_rating":1
#     },
#     {
#         "user_id":296,
#         "place_id":162,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":225,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":29,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":296,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":69,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":216,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":174,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":177,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":303,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":97,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":259,
#         "place_rating":3
#     },
#     {
#         "user_id":296,
#         "place_id":225,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":177,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":125,
#         "place_rating":4
#     },
#     {
#         "user_id":296,
#         "place_id":64,
#         "place_rating":2
#     },
#     {
#         "user_id":296,
#         "place_id":280,
#         "place_rating":3
#     },
#     {
#         "user_id":296,
#         "place_id":21,
#         "place_rating":3
#     },
#     {
#         "user_id":296,
#         "place_id":351,
#         "place_rating":5
#     },
#     {
#         "user_id":296,
#         "place_id":427,
#         "place_rating":5
#     },
#     {
#         "user_id":296,
#         "place_id":407,
#         "place_rating":3
#     },
#     {
#         "user_id":296,
#         "place_id":113,
#         "place_rating":2
#     },
#     {
#         "user_id":297,
#         "place_id":384,
#         "place_rating":2
#     },
#     {
#         "user_id":297,
#         "place_id":77,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":241,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":287,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":418,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":299,
#         "place_rating":1
#     },
#     {
#         "user_id":297,
#         "place_id":417,
#         "place_rating":2
#     },
#     {
#         "user_id":297,
#         "place_id":199,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":105,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":217,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":38,
#         "place_rating":3
#     },
#     {
#         "user_id":297,
#         "place_id":107,
#         "place_rating":3
#     },
#     {
#         "user_id":297,
#         "place_id":392,
#         "place_rating":1
#     },
#     {
#         "user_id":297,
#         "place_id":191,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":430,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":88,
#         "place_rating":2
#     },
#     {
#         "user_id":297,
#         "place_id":54,
#         "place_rating":3
#     },
#     {
#         "user_id":297,
#         "place_id":95,
#         "place_rating":3
#     },
#     {
#         "user_id":297,
#         "place_id":429,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":437,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":234,
#         "place_rating":3
#     },
#     {
#         "user_id":297,
#         "place_id":170,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":386,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":234,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":209,
#         "place_rating":3
#     },
#     {
#         "user_id":297,
#         "place_id":297,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":15,
#         "place_rating":1
#     },
#     {
#         "user_id":297,
#         "place_id":424,
#         "place_rating":2
#     },
#     {
#         "user_id":297,
#         "place_id":41,
#         "place_rating":1
#     },
#     {
#         "user_id":297,
#         "place_id":187,
#         "place_rating":2
#     },
#     {
#         "user_id":297,
#         "place_id":56,
#         "place_rating":4
#     },
#     {
#         "user_id":297,
#         "place_id":332,
#         "place_rating":1
#     },
#     {
#         "user_id":297,
#         "place_id":401,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":23,
#         "place_rating":1
#     },
#     {
#         "user_id":297,
#         "place_id":7,
#         "place_rating":5
#     },
#     {
#         "user_id":297,
#         "place_id":418,
#         "place_rating":2
#     },
#     {
#         "user_id":298,
#         "place_id":335,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":15,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":220,
#         "place_rating":3
#     },
#     {
#         "user_id":298,
#         "place_id":283,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":236,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":159,
#         "place_rating":1
#     },
#     {
#         "user_id":298,
#         "place_id":137,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":117,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":126,
#         "place_rating":1
#     },
#     {
#         "user_id":298,
#         "place_id":143,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":437,
#         "place_rating":3
#     },
#     {
#         "user_id":298,
#         "place_id":171,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":238,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":120,
#         "place_rating":2
#     },
#     {
#         "user_id":298,
#         "place_id":240,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":392,
#         "place_rating":3
#     },
#     {
#         "user_id":298,
#         "place_id":240,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":83,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":358,
#         "place_rating":1
#     },
#     {
#         "user_id":298,
#         "place_id":201,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":176,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":39,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":342,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":424,
#         "place_rating":1
#     },
#     {
#         "user_id":298,
#         "place_id":255,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":268,
#         "place_rating":2
#     },
#     {
#         "user_id":298,
#         "place_id":307,
#         "place_rating":2
#     },
#     {
#         "user_id":298,
#         "place_id":391,
#         "place_rating":4
#     },
#     {
#         "user_id":298,
#         "place_id":254,
#         "place_rating":5
#     },
#     {
#         "user_id":298,
#         "place_id":350,
#         "place_rating":4
#     },
#     {
#         "user_id":299,
#         "place_id":25,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":224,
#         "place_rating":5
#     },
#     {
#         "user_id":299,
#         "place_id":244,
#         "place_rating":4
#     },
#     {
#         "user_id":299,
#         "place_id":295,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":420,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":290,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":13,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":66,
#         "place_rating":5
#     },
#     {
#         "user_id":299,
#         "place_id":153,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":402,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":281,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":341,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":407,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":47,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":409,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":8,
#         "place_rating":4
#     },
#     {
#         "user_id":299,
#         "place_id":109,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":290,
#         "place_rating":5
#     },
#     {
#         "user_id":299,
#         "place_id":373,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":21,
#         "place_rating":5
#     },
#     {
#         "user_id":299,
#         "place_id":328,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":280,
#         "place_rating":4
#     },
#     {
#         "user_id":299,
#         "place_id":220,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":267,
#         "place_rating":4
#     },
#     {
#         "user_id":299,
#         "place_id":384,
#         "place_rating":5
#     },
#     {
#         "user_id":299,
#         "place_id":41,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":101,
#         "place_rating":4
#     },
#     {
#         "user_id":299,
#         "place_id":12,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":275,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":72,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":304,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":121,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":383,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":182,
#         "place_rating":1
#     },
#     {
#         "user_id":299,
#         "place_id":430,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":37,
#         "place_rating":3
#     },
#     {
#         "user_id":299,
#         "place_id":28,
#         "place_rating":2
#     },
#     {
#         "user_id":299,
#         "place_id":407,
#         "place_rating":5
#     },
#     {
#         "user_id":299,
#         "place_id":105,
#         "place_rating":3
#     },
#     {
#         "user_id":300,
#         "place_id":397,
#         "place_rating":2
#     },
#     {
#         "user_id":300,
#         "place_id":221,
#         "place_rating":3
#     },
#     {
#         "user_id":300,
#         "place_id":69,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":200,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":69,
#         "place_rating":3
#     },
#     {
#         "user_id":300,
#         "place_id":285,
#         "place_rating":5
#     },
#     {
#         "user_id":300,
#         "place_id":343,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":144,
#         "place_rating":5
#     },
#     {
#         "user_id":300,
#         "place_id":107,
#         "place_rating":2
#     },
#     {
#         "user_id":300,
#         "place_id":69,
#         "place_rating":1
#     },
#     {
#         "user_id":300,
#         "place_id":324,
#         "place_rating":3
#     },
#     {
#         "user_id":300,
#         "place_id":8,
#         "place_rating":1
#     },
#     {
#         "user_id":300,
#         "place_id":323,
#         "place_rating":1
#     },
#     {
#         "user_id":300,
#         "place_id":193,
#         "place_rating":5
#     },
#     {
#         "user_id":300,
#         "place_id":435,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":346,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":255,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":363,
#         "place_rating":1
#     },
#     {
#         "user_id":300,
#         "place_id":416,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":108,
#         "place_rating":5
#     },
#     {
#         "user_id":300,
#         "place_id":103,
#         "place_rating":5
#     },
#     {
#         "user_id":300,
#         "place_id":425,
#         "place_rating":2
#     },
#     {
#         "user_id":300,
#         "place_id":64,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":311,
#         "place_rating":3
#     },
#     {
#         "user_id":300,
#         "place_id":279,
#         "place_rating":4
#     },
#     {
#         "user_id":300,
#         "place_id":163,
#         "place_rating":2
#     }
# ]

# %%
#Dataset Class

class RatingDataset(torch.utils.data.Dataset):
    def __init__(self, num_negatives=5):
        self.users = rating_df[rating_df['implicit_label'] == 1]["user_id"].values
        self.positives = rating_df[rating_df['implicit_label'] == 1].groupby('user_id')['place_id'].apply(set).to_dict()

        self.num_negatives = num_negatives
        
        self.user_item_pairs = []
        for user, pos_items in self.positives.items():
            for item in pos_items:
                self.user_item_pairs.append((user, item))

    def __len__(self):
        return len(self.users) * (1 + self.num_negatives)

    def __getitem__(self, idx):
        group_size = 1 + self.num_negatives
        pos_idx = idx // group_size
        offset = idx % group_size

        user, pos_item = self.user_item_pairs[pos_idx]

        if offset == 0:
            # Positive sample
            return torch.tensor(user), torch.tensor(pos_item), torch.tensor(1.0)
        else:
            # Negative sample
            while True:
                neg_item = random.randint(0, place_len - 1)
                if neg_item not in self.positives.get(user, set()):
                    return torch.tensor(user), torch.tensor(neg_item), torch.tensor(0.0)
    
dataset = RatingDataset()

# %%
class EvaluationDataset(torch.utils.data.Dataset):
    def __init__(self):
        self.users = torch.tensor(rating_df["user_id"].values, dtype=torch.long)
        self.places = torch.tensor(rating_df["place_id"].values, dtype=torch.long)
        self.labels = torch.tensor(rating_df["implicit_label"].values, dtype=torch.float)

    def __len__(self):
        return len(self.users)

    def __getitem__(self, idx):
        return self.users[idx], self.places[idx], self.labels[idx]

# %%
class NeuMF(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim=32):
        super(NeuMF, self).__init__()
        
        # GMF embeddings
        self.gmf_user = nn.Embedding(num_users, embedding_dim)
        self.gmf_item = nn.Embedding(num_items, embedding_dim)

        # MLP embeddings
        self.mlp_user = nn.Embedding(num_users, embedding_dim)
        self.mlp_item = nn.Embedding(num_items, embedding_dim)

        # MLP layers
        self.linear_1 = nn.Linear(embedding_dim * 2, 64)
        self.relu_1 = nn.LeakyReLU()
        self.linear_2 = nn.Linear(64, 32)
        self.relu_2 = nn.LeakyReLU()
        self.linear_3 = nn.Linear(32, 16)

        # NeuMF layer (concat GMF and MLP)
        final_input_dim = embedding_dim + 16
        self.output_layer = nn.Linear(final_input_dim, 1)
    
    def forward(self, user_ids, item_ids):
        # GMF part
        gmf_u = self.gmf_user(user_ids)
        gmf_i = self.gmf_item(item_ids)
        gmf_output = gmf_u * gmf_i  # element-wise product

        # MLP part
        mlp_u = self.mlp_user(user_ids)
        mlp_i = self.mlp_item(item_ids)
        mlp_input = torch.cat([mlp_u, mlp_i], dim=-1)

        x = self.linear_1(mlp_input)
        x = self.relu_1(x)
        x = self.linear_2(x)
        x = self.relu_2(x)
        mlp_output = self.linear_3(x)

        # Concatenate GMF and MLP output
        concat = torch.cat([gmf_output, mlp_output], dim=-1)
        logits = self.output_layer(concat)
        return logits
    
model = NeuMF(user_len, place_len)
model = model.to(device)

# %%
# class MatrixFactorization(nn.Module):
#     def __init__(self, num_users, num_items, embedding_dim=64):
#         super(MatrixFactorization, self).__init__()
#         self.user_embedding = nn.Embedding(num_users, embedding_dim)
#         self.item_embedding = nn.Embedding(num_items, embedding_dim)

#         # Optional: Initialize embeddings
#         nn.init.normal_(self.user_embedding.weight, std=0.01)
#         nn.init.normal_(self.item_embedding.weight, std=0.01)

#     def forward(self, user_ids, item_ids):
#         user_vecs = self.user_embedding(user_ids)  # shape: (batch_size, embedding_dim)
#         item_vecs = self.item_embedding(item_ids)  # shape: (batch_size, embedding_dim)

#         # Dot product of user and item embeddings
#         scores = (user_vecs * item_vecs).sum(dim=1, keepdim=True)  # shape: (batch_size, 1)
#         return scores

# model = MatrixFactorization(user_len, place_len)
# model = model.to(device)

# %%
# class NeuralCF(nn.Module):
#     def __init__(self, num_users, num_items, embedding_dim=32):
#         super().__init__()
#         self.user_embedding = nn.Embedding(num_users, embedding_dim)
#         self.item_embedding = nn.Embedding(num_items, embedding_dim)

#         # MLP layers (simple 2-layer example)
#         self.fc1 = nn.Linear(embedding_dim * 2, 64)
#         self.relu1 = nn.ReLU()
#         self.fc2 = nn.Linear(64, 32)
#         self.relu2 = nn.ReLU()
#         self.output = nn.Linear(32, 1)  # output raw logits for BCEWithLogitsLoss

#     def forward(self, user_ids, item_ids):
#         user_vec = self.user_embedding(user_ids)
#         item_vec = self.item_embedding(item_ids)
#         x = torch.cat([user_vec, item_vec], dim=-1)  # concat user and item embeddings
#         x = self.relu1(self.fc1(x))
#         x = self.relu2(self.fc2(x))
#         logits = self.output(x)
#         return logits  # raw score, use sigmoid or BCEWithLogitsLoss
    
# model = NeuralCF(num_users=user_len, num_items=place_len, embedding_dim=32).to(device)

# %%
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.0001)

epochs = 100

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_dataset = RatingDataset(num_negatives=10)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True)

test_dataset = EvaluationDataset()
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128, shuffle=False)

# %%
def hit_at_k(user_item_scores, user_item_labels, k):
    hits = []
    for user in user_item_scores:
        scores = np.array(user_item_scores[user])
        labels = np.array(user_item_labels[user])
        if labels.sum() == 0:  # no positives for user, skip
            continue
        # Get indices of top-k scores
        top_k_indices = scores.argsort()[::-1][:k]
        # Check if any of the top-k are positive
        hits.append(1 if labels[top_k_indices].sum() > 0 else 0)
    return np.mean(hits)

# %%
for epoch in range(epochs):
    model.train()
    train_correct = 0
    train_loss_total = 0.0

    for x1, x2, y in train_loader:
        x1, x2, y = x1.to(device), x2.to(device), y.to(device)
        y = y.unsqueeze(1).float()
        y_logits = model(x1, x2)
        y_preds = (y_logits > 0)

        train_correct += (y_preds == y).sum().item()
        train_loss = loss_fn(y_logits, y)
        train_loss_total += train_loss.item()

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

    model.eval()

    all_scores = []
    all_labels = []
    all_users = []

    test_loss_total = 0.0
    test_correct = 0

    with torch.inference_mode():
        for x1, x2, y in test_loader:
            x1, x2, y = x1.to(device), x2.to(device), y.to(device)
            y = y.unsqueeze(1).float()
            y_logits = model(x1, x2)
            y_preds = (y_logits > 0)

            test_correct += (y_preds == y).sum().item()

            all_scores.extend(y_logits.squeeze().cpu().tolist())
            all_labels.extend(y.squeeze().cpu().tolist())
            # Assuming you have a user tensor x1 (user ids)
            all_users.extend(x1.cpu().tolist())

    # ROC-AUC (on entire test set)
    roc_auc = roc_auc_score(all_labels, all_scores)

    # Group scores and labels by user for hit@k
    user_item_scores = {}
    user_item_labels = {}

    for user, score, label in zip(all_users, all_scores, all_labels):
        if user not in user_item_scores:
            user_item_scores[user] = []
            user_item_labels[user] = []
        user_item_scores[user].append(score)
        user_item_labels[user].append(label)

    k = 2
    hit_k = hit_at_k(user_item_scores, user_item_labels, k)

    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_loss_total / len(train_loader):.4f} | "
          f"ROC-AUC: {roc_auc:.4f} | "
          f"Hit@{k}: {hit_k:.4f}")
# Out:
# Epoch 1/100 | Train Loss: 0.6931 | ROC-AUC: 0.5863 | Hit@2: 0.8239
# Epoch 2/100 | Train Loss: 0.6925 | ROC-AUC: 0.5499 | Hit@2: 0.9070
# Epoch 3/100 | Train Loss: 0.6855 | ROC-AUC: 0.4768 | Hit@2: 0.7940
# Epoch 4/100 | Train Loss: 0.6567 | ROC-AUC: 0.4713 | Hit@2: 0.8040
# Epoch 5/100 | Train Loss: 0.6053 | ROC-AUC: 0.4684 | Hit@2: 0.7674
# Epoch 6/100 | Train Loss: 0.5468 | ROC-AUC: 0.4698 | Hit@2: 0.8073
# Epoch 7/100 | Train Loss: 0.4927 | ROC-AUC: 0.4749 | Hit@2: 0.8073
# Epoch 8/100 | Train Loss: 0.4478 | ROC-AUC: 0.4788 | Hit@2: 0.8106
# Epoch 9/100 | Train Loss: 0.4128 | ROC-AUC: 0.4837 | Hit@2: 0.8106
# Epoch 10/100 | Train Loss: 0.3863 | ROC-AUC: 0.4895 | Hit@2: 0.8073
# Epoch 11/100 | Train Loss: 0.3670 | ROC-AUC: 0.4938 | Hit@2: 0.7907
# Epoch 12/100 | Train Loss: 0.3528 | ROC-AUC: 0.4969 | Hit@2: 0.7874
# Epoch 13/100 | Train Loss: 0.3421 | ROC-AUC: 0.5014 | Hit@2: 0.7774
# Epoch 14/100 | Train Loss: 0.3343 | ROC-AUC: 0.5061 | Hit@2: 0.7907
# Epoch 15/100 | Train Loss: 0.3285 | ROC-AUC: 0.5098 | Hit@2: 0.7940
# Epoch 16/100 | Train Loss: 0.3244 | ROC-AUC: 0.5131 | Hit@2: 0.7907
# Epoch 17/100 | Train Loss: 0.3208 | ROC-AUC: 0.5166 | Hit@2: 0.7907
# Epoch 18/100 | Train Loss: 0.3185 | ROC-AUC: 0.5197 | Hit@2: 0.7907
# Epoch 19/100 | Train Loss: 0.3161 | ROC-AUC: 0.5229 | Hit@2: 0.7940
# Epoch 20/100 | Train Loss: 0.3147 | ROC-AUC: 0.5262 | Hit@2: 0.7874
# Epoch 21/100 | Train Loss: 0.3134 | ROC-AUC: 0.5290 | Hit@2: 0.7774
# Epoch 22/100 | Train Loss: 0.3124 | ROC-AUC: 0.5315 | Hit@2: 0.7874
# Epoch 23/100 | Train Loss: 0.3118 | ROC-AUC: 0.5334 | Hit@2: 0.7907
# Epoch 24/100 | Train Loss: 0.3111 | ROC-AUC: 0.5351 | Hit@2: 0.7907
# Epoch 25/100 | Train Loss: 0.3105 | ROC-AUC: 0.5361 | Hit@2: 0.8106
# Epoch 26/100 | Train Loss: 0.3102 | ROC-AUC: 0.5377 | Hit@2: 0.8040
# Epoch 27/100 | Train Loss: 0.3097 | ROC-AUC: 0.5396 | Hit@2: 0.8007
# Epoch 28/100 | Train Loss: 0.3094 | ROC-AUC: 0.5410 | Hit@2: 0.8007
# Epoch 29/100 | Train Loss: 0.3091 | ROC-AUC: 0.5420 | Hit@2: 0.8007
# Epoch 30/100 | Train Loss: 0.3092 | ROC-AUC: 0.5427 | Hit@2: 0.7940
# Epoch 31/100 | Train Loss: 0.3088 | ROC-AUC: 0.5441 | Hit@2: 0.7940
# Epoch 32/100 | Train Loss: 0.3085 | ROC-AUC: 0.5445 | Hit@2: 0.7741
# Epoch 33/100 | Train Loss: 0.3086 | ROC-AUC: 0.5455 | Hit@2: 0.7874
# Epoch 34/100 | Train Loss: 0.3082 | ROC-AUC: 0.5465 | Hit@2: 0.7841
# Epoch 35/100 | Train Loss: 0.3082 | ROC-AUC: 0.5472 | Hit@2: 0.7940
# Epoch 36/100 | Train Loss: 0.3081 | ROC-AUC: 0.5477 | Hit@2: 0.7807
# Epoch 37/100 | Train Loss: 0.3081 | ROC-AUC: 0.5485 | Hit@2: 0.7807
# Epoch 38/100 | Train Loss: 0.3080 | ROC-AUC: 0.5494 | Hit@2: 0.7874
# Epoch 39/100 | Train Loss: 0.3081 | ROC-AUC: 0.5496 | Hit@2: 0.7741
# Epoch 40/100 | Train Loss: 0.3080 | ROC-AUC: 0.5501 | Hit@2: 0.7841
# Epoch 41/100 | Train Loss: 0.3080 | ROC-AUC: 0.5506 | Hit@2: 0.7741
# Epoch 42/100 | Train Loss: 0.3079 | ROC-AUC: 0.5508 | Hit@2: 0.7674
# Epoch 43/100 | Train Loss: 0.3078 | ROC-AUC: 0.5511 | Hit@2: 0.7608
# Epoch 44/100 | Train Loss: 0.3076 | ROC-AUC: 0.5517 | Hit@2: 0.7608
# Epoch 45/100 | Train Loss: 0.3077 | ROC-AUC: 0.5518 | Hit@2: 0.7608
# Epoch 46/100 | Train Loss: 0.3079 | ROC-AUC: 0.5522 | Hit@2: 0.7774
# Epoch 47/100 | Train Loss: 0.3078 | ROC-AUC: 0.5523 | Hit@2: 0.7874
# Epoch 48/100 | Train Loss: 0.3079 | ROC-AUC: 0.5527 | Hit@2: 0.7940
# Epoch 49/100 | Train Loss: 0.3077 | ROC-AUC: 0.5527 | Hit@2: 0.8073
# Epoch 50/100 | Train Loss: 0.3076 | ROC-AUC: 0.5530 | Hit@2: 0.8007
# Epoch 51/100 | Train Loss: 0.3081 | ROC-AUC: 0.5529 | Hit@2: 0.8040
# Epoch 52/100 | Train Loss: 0.3077 | ROC-AUC: 0.5530 | Hit@2: 0.8106
# Epoch 53/100 | Train Loss: 0.3079 | ROC-AUC: 0.5527 | Hit@2: 0.8173
# Epoch 54/100 | Train Loss: 0.3077 | ROC-AUC: 0.5530 | Hit@2: 0.8073
# Epoch 55/100 | Train Loss: 0.3079 | ROC-AUC: 0.5529 | Hit@2: 0.7973
# Epoch 56/100 | Train Loss: 0.3076 | ROC-AUC: 0.5527 | Hit@2: 0.8073
# Epoch 57/100 | Train Loss: 0.3080 | ROC-AUC: 0.5526 | Hit@2: 0.7973
# Epoch 58/100 | Train Loss: 0.3077 | ROC-AUC: 0.5527 | Hit@2: 0.8073
# Epoch 59/100 | Train Loss: 0.3078 | ROC-AUC: 0.5533 | Hit@2: 0.8073
# Epoch 60/100 | Train Loss: 0.3079 | ROC-AUC: 0.5531 | Hit@2: 0.8040
# Epoch 61/100 | Train Loss: 0.3078 | ROC-AUC: 0.5529 | Hit@2: 0.7907
# Epoch 62/100 | Train Loss: 0.3077 | ROC-AUC: 0.5529 | Hit@2: 0.7741
# Epoch 63/100 | Train Loss: 0.3076 | ROC-AUC: 0.5535 | Hit@2: 0.7973
# Epoch 64/100 | Train Loss: 0.3077 | ROC-AUC: 0.5535 | Hit@2: 0.8073
# Epoch 65/100 | Train Loss: 0.3078 | ROC-AUC: 0.5536 | Hit@2: 0.8007
# Epoch 66/100 | Train Loss: 0.3075 | ROC-AUC: 0.5536 | Hit@2: 0.8073
# Epoch 67/100 | Train Loss: 0.3077 | ROC-AUC: 0.5538 | Hit@2: 0.8040
# Epoch 68/100 | Train Loss: 0.3076 | ROC-AUC: 0.5539 | Hit@2: 0.8140
# Epoch 69/100 | Train Loss: 0.3079 | ROC-AUC: 0.5539 | Hit@2: 0.8173
# Epoch 70/100 | Train Loss: 0.3077 | ROC-AUC: 0.5539 | Hit@2: 0.8140
# Epoch 71/100 | Train Loss: 0.3077 | ROC-AUC: 0.5538 | Hit@2: 0.7940
# Epoch 72/100 | Train Loss: 0.3078 | ROC-AUC: 0.5538 | Hit@2: 0.7973
# Epoch 73/100 | Train Loss: 0.3076 | ROC-AUC: 0.5538 | Hit@2: 0.7940
# Epoch 74/100 | Train Loss: 0.3078 | ROC-AUC: 0.5539 | Hit@2: 0.7907
# Epoch 75/100 | Train Loss: 0.3077 | ROC-AUC: 0.5537 | Hit@2: 0.7940
# Epoch 76/100 | Train Loss: 0.3077 | ROC-AUC: 0.5542 | Hit@2: 0.8007
# Epoch 77/100 | Train Loss: 0.3077 | ROC-AUC: 0.5542 | Hit@2: 0.7807
# Epoch 78/100 | Train Loss: 0.3076 | ROC-AUC: 0.5546 | Hit@2: 0.8106
# Epoch 79/100 | Train Loss: 0.3075 | ROC-AUC: 0.5544 | Hit@2: 0.8073
# Epoch 80/100 | Train Loss: 0.3080 | ROC-AUC: 0.5545 | Hit@2: 0.8140
# Epoch 81/100 | Train Loss: 0.3077 | ROC-AUC: 0.5545 | Hit@2: 0.8073
# Epoch 82/100 | Train Loss: 0.3076 | ROC-AUC: 0.5544 | Hit@2: 0.8040
# Epoch 83/100 | Train Loss: 0.3078 | ROC-AUC: 0.5544 | Hit@2: 0.8073
# Epoch 84/100 | Train Loss: 0.3076 | ROC-AUC: 0.5543 | Hit@2: 0.8140
# Epoch 85/100 | Train Loss: 0.3077 | ROC-AUC: 0.5542 | Hit@2: 0.8106
# Epoch 86/100 | Train Loss: 0.3077 | ROC-AUC: 0.5541 | Hit@2: 0.8073
# Epoch 87/100 | Train Loss: 0.3079 | ROC-AUC: 0.5543 | Hit@2: 0.8140
# Epoch 88/100 | Train Loss: 0.3080 | ROC-AUC: 0.5542 | Hit@2: 0.8173
# Epoch 89/100 | Train Loss: 0.3076 | ROC-AUC: 0.5541 | Hit@2: 0.8040
# Epoch 90/100 | Train Loss: 0.3079 | ROC-AUC: 0.5540 | Hit@2: 0.8073
# Epoch 91/100 | Train Loss: 0.3079 | ROC-AUC: 0.5537 | Hit@2: 0.8073
# Epoch 92/100 | Train Loss: 0.3075 | ROC-AUC: 0.5541 | Hit@2: 0.8173
# Epoch 93/100 | Train Loss: 0.3079 | ROC-AUC: 0.5541 | Hit@2: 0.8040
# Epoch 94/100 | Train Loss: 0.3078 | ROC-AUC: 0.5542 | Hit@2: 0.8007
# Epoch 95/100 | Train Loss: 0.3077 | ROC-AUC: 0.5544 | Hit@2: 0.8040
# Epoch 96/100 | Train Loss: 0.3078 | ROC-AUC: 0.5542 | Hit@2: 0.8007
# Epoch 97/100 | Train Loss: 0.3076 | ROC-AUC: 0.5544 | Hit@2: 0.7973
# Epoch 98/100 | Train Loss: 0.3075 | ROC-AUC: 0.5544 | Hit@2: 0.8007
# Epoch 99/100 | Train Loss: 0.3077 | ROC-AUC: 0.5544 | Hit@2: 0.7973
# Epoch 100/100 | Train Loss: 0.3079 | ROC-AUC: 0.5539 | Hit@2: 0.7973

# %%
# NeuMF Epoch 100/100 | Train Loss: 0.2422 | ROC-AUC: 0.8259 | Hit@2: 0.9900
# NeuCF Epoch 100/100 | Train Loss: 0.2658 | ROC-AUC: 0.7687 | Hit@2: 0.9568
# Matrix Factorization Epoch 100/100 | Train Loss: 0.3079 | ROC-AUC: 0.5539 | Hit@2: 0.7973
torch.save(model.state_dict(), "model.pth")

# %%
# del model
# del train_loader
# torch.cuda.empty_cache()
