# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
user_df = pd.read_csv("./data/user.csv")
rating_df = pd.read_csv("./data/tourism_rating.csv")
place_df = pd.read_csv("./data/tourism_with_id.csv", usecols=["Place_Id", "Place_Name", "City", "Rating"])

# %%
user_df = user_df.rename(columns={"User_Id": "user_id", "Location": "location", "Age": "age"})
rating_df = rating_df.rename(columns={"User_Id": "user_id", "Place_Id": "place_id", "Place_Ratings": "place_rating"})
place_df = place_df.rename(columns={"Place_Id": "place_id", "Place_Name": "place_name", "City": "city", "Rating": "rating"})

# %%
# print(user_df.describe(), "\n")
# print(user_df.isnull().sum(), "\n")
# print(user_df[user_df.duplicated(keep=False)], "\n")

# print(rating_df.describe(), "\n")
# print(rating_df.isnull().sum(), "\n")
# print(rating_df[rating_df.duplicated(keep=False)], "\n")
rating_df = rating_df.drop_duplicates(subset=["user_id", "place_id"], keep="last")

# print(place_df.describe(), "\n")
# print(place_df.isnull().sum(), "\n")
# print(place_df[place_df.duplicated(keep=False)], "\n")

# %%
# Converting rating to interaction bool. (Explicit to Implicit)
rating_df["implicit_label"] = (rating_df["place_rating"] >= 3).astype(int)
user_len = rating_df["user_id"].nunique()
place_len = place_df["place_id"].nunique()
# rating_df
place_len
# Out:
# 437

# %%
#Dataset Class

class RatingDataset(torch.utils.data.Dataset):
    def __init__(self):
        self.users = torch.tensor(rating_df["user_id"].values - 1, dtype=torch.long)
        self.places = torch.tensor(rating_df["place_id"].values - 1, dtype=torch.long)
        self.labels = torch.tensor(rating_df["implicit_label"].values, dtype=torch.float)
    
    def __len__(self):
        return len(self.users)

    def __getitem__(self, idx):
        return self.users[idx], self.places[idx], self.labels[idx]
    
dataset = RatingDataset()

# %%
class NeuMF(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim=16):
        super(NeuMF, self).__init__()
        
        # GMF embeddings
        self.gmf_user = nn.Embedding(num_users, embedding_dim)
        self.gmf_item = nn.Embedding(num_items, embedding_dim)

        # MLP embeddings
        self.mlp_user = nn.Embedding(num_users, embedding_dim)
        self.mlp_item = nn.Embedding(num_items, embedding_dim)

        # MLP layers
        self.linear_1 = nn.Linear(embedding_dim * 2, 64)
        self.relu_1 = nn.LeakyReLU()
        self.linear_2 = nn.Linear(64, 32)
        self.relu_2 = nn.LeakyReLU()
        self.linear_3 = nn.Linear(32, 16)

        # NeuMF layer (concat GMF and MLP)
        final_input_dim = embedding_dim + 16
        self.output_layer = nn.Linear(final_input_dim, 1)
    
    def forward(self, user_ids, item_ids):
        # GMF part
        gmf_u = self.gmf_user(user_ids)
        gmf_i = self.gmf_item(item_ids)
        gmf_output = gmf_u * gmf_i  # element-wise product

        # MLP part
        mlp_u = self.mlp_user(user_ids)
        mlp_i = self.mlp_item(item_ids)
        mlp_input = torch.cat([mlp_u, mlp_i], dim=-1)

        x = self.linear_1(mlp_input)
        x = self.relu_1(x)
        x = self.linear_2(x)
        x = self.relu_2(x)
        mlp_output = self.linear_3(x)

        # Concatenate GMF and MLP output
        concat = torch.cat([gmf_output, mlp_output], dim=-1)
        logits = self.output_layer(concat)
        return logits
    
model = NeuMF(user_len, place_len)
model = model.to(device)

# %%
# class NeuralCF(nn.Module):
#     def __init__(self, num_users, num_items, embedding_dim=32):
#         super().__init__()
#         self.user_embedding = nn.Embedding(num_users, embedding_dim)
#         self.item_embedding = nn.Embedding(num_items, embedding_dim)

#         # MLP layers (simple 2-layer example)
#         self.fc1 = nn.Linear(embedding_dim * 2, 64)
#         self.relu1 = nn.ReLU()
#         self.fc2 = nn.Linear(64, 32)
#         self.relu2 = nn.ReLU()
#         self.output = nn.Linear(32, 1)  # output raw logits for BCEWithLogitsLoss

#     def forward(self, user_ids, item_ids):
#         user_vec = self.user_embedding(user_ids)
#         item_vec = self.item_embedding(item_ids)
#         x = torch.cat([user_vec, item_vec], dim=-1)  # concat user and item embeddings
#         x = self.relu1(self.fc1(x))
#         x = self.relu2(self.fc2(x))
#         logits = self.output(x)
#         return logits  # raw score, use sigmoid or BCEWithLogitsLoss
    
# model = NeuralCF(num_users=user_len, num_items=place_len, embedding_dim=32).to(device)

# %%
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=0.001)

epochs = 100

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
def precision_at_k(y_scores, y_true, k):
    # Sort scores and true labels by descending score
    indices = np.argsort(y_scores)[::-1]  # highest scores first
    top_k_indices = indices[:k]
    
    # Get top-k predicted labels and their ground truths
    top_k_true = np.take(y_true, top_k_indices)
    
    # Count relevant items (assumes y_true are 0 or 1)
    return np.sum(top_k_true) / k

# %%
import numpy as np

def precision_at_k(y_scores, y_true, k):
    # Sort scores and true labels by descending score
    indices = np.argsort(y_scores)[::-1]  # highest scores first
    top_k_indices = indices[:k]
    
    # Get top-k predicted labels and their ground truths
    top_k_true = np.take(y_true, top_k_indices)
    
    # Count relevant items (assumes y_true are 0 or 1)
    return np.sum(top_k_true) / k


for epoch in range(epochs):
    model.train()
    train_correct, test_correct = 0, 0
    train_loss_total, test_loss_total = 0, 0

    for x1, x2, y in train_loader:
        x1, x2, y = x1.to(device), x2.to(device), y.to(device)
        y = y.unsqueeze(1)
        y_logits = model(x1, x2)
        y_preds = (y_logits > 0)
        
        train_correct += (y_preds == y).sum().item()
        train_loss = loss_fn(y_logits, y) 
        train_loss_total += train_loss.item()

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

    # eval
    model.eval()
    all_scores = []
    all_labels = []

    with torch.inference_mode():
        for x1, x2, y in test_loader:
            x1, x2, y = x1.to(device), x2.to(device), y.to(device)
            y = y.unsqueeze(1)
            y_logits = model(x1, x2)
            y_preds = (y_logits > 0)

            test_correct += (y_preds == y).sum().item()
            test_loss = loss_fn(y_logits, y) 
            test_loss_total += test_loss.item()

            # Collect scores and labels for P@K
            all_scores.extend(torch.sigmoid(y_logits).cpu().numpy().flatten())
            all_labels.extend(y.cpu().numpy().flatten())

    # Compute Precision@10
    p_at_10 = precision_at_k(all_scores, all_labels, k=10)

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss_total/len(train_loader):.4f}, "
          f"Train Acc: {train_correct/train_size:.2f}, Test Loss: {test_loss_total/len(test_loader):.4f}, "
          f"Test Acc: {test_correct/test_size:.2f}, P@10: {p_at_10:.4f}")
# Out:
# Epoch 1/100, Train Loss: 0.7036, Train Acc: 0.51, Test Loss: 0.6885, Test Acc: 0.56, P@10: 0.7000
# Epoch 2/100, Train Loss: 0.6869, Train Acc: 0.56, Test Loss: 0.6717, Test Acc: 0.60, P@10: 0.7000
# Epoch 3/100, Train Loss: 0.6776, Train Acc: 0.60, Test Loss: 0.6659, Test Acc: 0.63, P@10: 0.7000
# Epoch 4/100, Train Loss: 0.6746, Train Acc: 0.61, Test Loss: 0.6643, Test Acc: 0.63, P@10: 0.8000
# Epoch 5/100, Train Loss: 0.6727, Train Acc: 0.61, Test Loss: 0.6633, Test Acc: 0.63, P@10: 0.8000
# Epoch 6/100, Train Loss: 0.6711, Train Acc: 0.61, Test Loss: 0.6626, Test Acc: 0.63, P@10: 0.8000
# Epoch 7/100, Train Loss: 0.6698, Train Acc: 0.62, Test Loss: 0.6619, Test Acc: 0.63, P@10: 0.8000
# Epoch 8/100, Train Loss: 0.6685, Train Acc: 0.62, Test Loss: 0.6610, Test Acc: 0.63, P@10: 0.8000
# Epoch 9/100, Train Loss: 0.6673, Train Acc: 0.62, Test Loss: 0.6605, Test Acc: 0.63, P@10: 0.8000
# Epoch 10/100, Train Loss: 0.6664, Train Acc: 0.62, Test Loss: 0.6600, Test Acc: 0.63, P@10: 0.8000
# Epoch 11/100, Train Loss: 0.6654, Train Acc: 0.62, Test Loss: 0.6595, Test Acc: 0.63, P@10: 0.8000
# Epoch 12/100, Train Loss: 0.6647, Train Acc: 0.62, Test Loss: 0.6591, Test Acc: 0.63, P@10: 0.8000
# Epoch 13/100, Train Loss: 0.6637, Train Acc: 0.62, Test Loss: 0.6590, Test Acc: 0.63, P@10: 0.8000
# Epoch 14/100, Train Loss: 0.6631, Train Acc: 0.62, Test Loss: 0.6587, Test Acc: 0.63, P@10: 0.8000
# Epoch 15/100, Train Loss: 0.6624, Train Acc: 0.62, Test Loss: 0.6587, Test Acc: 0.63, P@10: 0.8000
# Epoch 16/100, Train Loss: 0.6618, Train Acc: 0.62, Test Loss: 0.6585, Test Acc: 0.63, P@10: 0.8000
# Epoch 17/100, Train Loss: 0.6612, Train Acc: 0.62, Test Loss: 0.6582, Test Acc: 0.63, P@10: 0.8000
# Epoch 18/100, Train Loss: 0.6606, Train Acc: 0.62, Test Loss: 0.6580, Test Acc: 0.63, P@10: 0.9000
# Epoch 19/100, Train Loss: 0.6601, Train Acc: 0.62, Test Loss: 0.6579, Test Acc: 0.63, P@10: 0.9000
# Epoch 20/100, Train Loss: 0.6596, Train Acc: 0.62, Test Loss: 0.6578, Test Acc: 0.63, P@10: 0.8000
# Epoch 21/100, Train Loss: 0.6591, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.9000
# Epoch 22/100, Train Loss: 0.6586, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.9000
# Epoch 23/100, Train Loss: 0.6582, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.9000
# Epoch 24/100, Train Loss: 0.6578, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.9000
# Epoch 25/100, Train Loss: 0.6573, Train Acc: 0.62, Test Loss: 0.6574, Test Acc: 0.63, P@10: 0.9000
# Epoch 26/100, Train Loss: 0.6569, Train Acc: 0.62, Test Loss: 0.6575, Test Acc: 0.63, P@10: 0.9000
# Epoch 27/100, Train Loss: 0.6564, Train Acc: 0.62, Test Loss: 0.6575, Test Acc: 0.63, P@10: 0.8000
# Epoch 28/100, Train Loss: 0.6560, Train Acc: 0.62, Test Loss: 0.6574, Test Acc: 0.63, P@10: 0.8000
# Epoch 29/100, Train Loss: 0.6556, Train Acc: 0.62, Test Loss: 0.6574, Test Acc: 0.63, P@10: 0.8000
# Epoch 30/100, Train Loss: 0.6552, Train Acc: 0.62, Test Loss: 0.6574, Test Acc: 0.63, P@10: 0.8000
# Epoch 31/100, Train Loss: 0.6547, Train Acc: 0.62, Test Loss: 0.6575, Test Acc: 0.63, P@10: 0.8000
# Epoch 32/100, Train Loss: 0.6543, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.7000
# Epoch 33/100, Train Loss: 0.6538, Train Acc: 0.62, Test Loss: 0.6575, Test Acc: 0.63, P@10: 0.7000
# Epoch 34/100, Train Loss: 0.6534, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.7000
# Epoch 35/100, Train Loss: 0.6529, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.7000
# Epoch 36/100, Train Loss: 0.6525, Train Acc: 0.62, Test Loss: 0.6576, Test Acc: 0.63, P@10: 0.6000
# Epoch 37/100, Train Loss: 0.6520, Train Acc: 0.62, Test Loss: 0.6578, Test Acc: 0.63, P@10: 0.6000
# Epoch 38/100, Train Loss: 0.6516, Train Acc: 0.62, Test Loss: 0.6577, Test Acc: 0.63, P@10: 0.6000
# Epoch 39/100, Train Loss: 0.6511, Train Acc: 0.62, Test Loss: 0.6578, Test Acc: 0.63, P@10: 0.7000
# Epoch 40/100, Train Loss: 0.6506, Train Acc: 0.62, Test Loss: 0.6578, Test Acc: 0.63, P@10: 0.6000
# Epoch 41/100, Train Loss: 0.6500, Train Acc: 0.62, Test Loss: 0.6580, Test Acc: 0.63, P@10: 0.6000
# Epoch 42/100, Train Loss: 0.6494, Train Acc: 0.62, Test Loss: 0.6581, Test Acc: 0.63, P@10: 0.6000
# Epoch 43/100, Train Loss: 0.6488, Train Acc: 0.62, Test Loss: 0.6584, Test Acc: 0.63, P@10: 0.5000
# Epoch 44/100, Train Loss: 0.6484, Train Acc: 0.62, Test Loss: 0.6583, Test Acc: 0.63, P@10: 0.5000
# Epoch 45/100, Train Loss: 0.6476, Train Acc: 0.63, Test Loss: 0.6586, Test Acc: 0.63, P@10: 0.5000
# Epoch 46/100, Train Loss: 0.6470, Train Acc: 0.63, Test Loss: 0.6585, Test Acc: 0.63, P@10: 0.5000
# Epoch 47/100, Train Loss: 0.6465, Train Acc: 0.63, Test Loss: 0.6587, Test Acc: 0.63, P@10: 0.5000
# Epoch 48/100, Train Loss: 0.6457, Train Acc: 0.63, Test Loss: 0.6589, Test Acc: 0.63, P@10: 0.5000
# Epoch 49/100, Train Loss: 0.6450, Train Acc: 0.63, Test Loss: 0.6593, Test Acc: 0.63, P@10: 0.5000
# Epoch 50/100, Train Loss: 0.6442, Train Acc: 0.63, Test Loss: 0.6596, Test Acc: 0.63, P@10: 0.5000
# Epoch 51/100, Train Loss: 0.6436, Train Acc: 0.63, Test Loss: 0.6598, Test Acc: 0.62, P@10: 0.5000
# Epoch 52/100, Train Loss: 0.6428, Train Acc: 0.63, Test Loss: 0.6601, Test Acc: 0.63, P@10: 0.6000
# Epoch 53/100, Train Loss: 0.6419, Train Acc: 0.63, Test Loss: 0.6605, Test Acc: 0.62, P@10: 0.7000
# Epoch 54/100, Train Loss: 0.6411, Train Acc: 0.63, Test Loss: 0.6610, Test Acc: 0.62, P@10: 0.8000
# Epoch 55/100, Train Loss: 0.6402, Train Acc: 0.63, Test Loss: 0.6615, Test Acc: 0.62, P@10: 0.8000
# Epoch 56/100, Train Loss: 0.6393, Train Acc: 0.64, Test Loss: 0.6619, Test Acc: 0.62, P@10: 0.8000
# Epoch 57/100, Train Loss: 0.6384, Train Acc: 0.64, Test Loss: 0.6627, Test Acc: 0.62, P@10: 0.7000
# Epoch 58/100, Train Loss: 0.6375, Train Acc: 0.64, Test Loss: 0.6630, Test Acc: 0.62, P@10: 0.7000
# Epoch 59/100, Train Loss: 0.6365, Train Acc: 0.64, Test Loss: 0.6634, Test Acc: 0.62, P@10: 0.8000
# Epoch 60/100, Train Loss: 0.6355, Train Acc: 0.64, Test Loss: 0.6642, Test Acc: 0.62, P@10: 0.9000
# Epoch 61/100, Train Loss: 0.6348, Train Acc: 0.64, Test Loss: 0.6647, Test Acc: 0.61, P@10: 0.9000
# Epoch 62/100, Train Loss: 0.6339, Train Acc: 0.64, Test Loss: 0.6653, Test Acc: 0.61, P@10: 0.9000
# Epoch 63/100, Train Loss: 0.6327, Train Acc: 0.64, Test Loss: 0.6660, Test Acc: 0.61, P@10: 0.9000
# Epoch 64/100, Train Loss: 0.6315, Train Acc: 0.64, Test Loss: 0.6671, Test Acc: 0.61, P@10: 0.9000
# Epoch 65/100, Train Loss: 0.6308, Train Acc: 0.64, Test Loss: 0.6678, Test Acc: 0.60, P@10: 0.9000
# Epoch 66/100, Train Loss: 0.6294, Train Acc: 0.65, Test Loss: 0.6684, Test Acc: 0.60, P@10: 0.9000
# Epoch 67/100, Train Loss: 0.6285, Train Acc: 0.65, Test Loss: 0.6690, Test Acc: 0.61, P@10: 0.9000
# Epoch 68/100, Train Loss: 0.6274, Train Acc: 0.65, Test Loss: 0.6698, Test Acc: 0.60, P@10: 0.9000
# Epoch 69/100, Train Loss: 0.6263, Train Acc: 0.65, Test Loss: 0.6705, Test Acc: 0.60, P@10: 0.9000
# Epoch 70/100, Train Loss: 0.6250, Train Acc: 0.65, Test Loss: 0.6725, Test Acc: 0.60, P@10: 0.9000
# Epoch 71/100, Train Loss: 0.6241, Train Acc: 0.65, Test Loss: 0.6725, Test Acc: 0.60, P@10: 0.9000
# Epoch 72/100, Train Loss: 0.6230, Train Acc: 0.65, Test Loss: 0.6738, Test Acc: 0.60, P@10: 0.9000
# Epoch 73/100, Train Loss: 0.6217, Train Acc: 0.65, Test Loss: 0.6745, Test Acc: 0.60, P@10: 0.9000
# Epoch 74/100, Train Loss: 0.6205, Train Acc: 0.65, Test Loss: 0.6756, Test Acc: 0.60, P@10: 0.9000
# Epoch 75/100, Train Loss: 0.6194, Train Acc: 0.66, Test Loss: 0.6767, Test Acc: 0.60, P@10: 0.9000
# Epoch 76/100, Train Loss: 0.6183, Train Acc: 0.66, Test Loss: 0.6778, Test Acc: 0.59, P@10: 0.9000
# Epoch 77/100, Train Loss: 0.6169, Train Acc: 0.66, Test Loss: 0.6793, Test Acc: 0.59, P@10: 0.9000
# Epoch 78/100, Train Loss: 0.6158, Train Acc: 0.66, Test Loss: 0.6799, Test Acc: 0.59, P@10: 1.0000
# Epoch 79/100, Train Loss: 0.6141, Train Acc: 0.66, Test Loss: 0.6815, Test Acc: 0.60, P@10: 1.0000
# Epoch 80/100, Train Loss: 0.6129, Train Acc: 0.66, Test Loss: 0.6821, Test Acc: 0.59, P@10: 1.0000
# Epoch 81/100, Train Loss: 0.6116, Train Acc: 0.67, Test Loss: 0.6839, Test Acc: 0.59, P@10: 1.0000
# Epoch 82/100, Train Loss: 0.6103, Train Acc: 0.67, Test Loss: 0.6851, Test Acc: 0.59, P@10: 1.0000
# Epoch 83/100, Train Loss: 0.6085, Train Acc: 0.67, Test Loss: 0.6865, Test Acc: 0.59, P@10: 1.0000
# Epoch 84/100, Train Loss: 0.6072, Train Acc: 0.67, Test Loss: 0.6881, Test Acc: 0.59, P@10: 1.0000
# Epoch 85/100, Train Loss: 0.6055, Train Acc: 0.67, Test Loss: 0.6896, Test Acc: 0.58, P@10: 0.9000
# Epoch 86/100, Train Loss: 0.6042, Train Acc: 0.67, Test Loss: 0.6907, Test Acc: 0.59, P@10: 0.9000
# Epoch 87/100, Train Loss: 0.6027, Train Acc: 0.67, Test Loss: 0.6929, Test Acc: 0.58, P@10: 0.9000
# Epoch 88/100, Train Loss: 0.6011, Train Acc: 0.68, Test Loss: 0.6941, Test Acc: 0.58, P@10: 0.9000
# Epoch 89/100, Train Loss: 0.5993, Train Acc: 0.68, Test Loss: 0.6961, Test Acc: 0.57, P@10: 0.9000
# Epoch 90/100, Train Loss: 0.5974, Train Acc: 0.68, Test Loss: 0.6973, Test Acc: 0.58, P@10: 0.8000
# Epoch 91/100, Train Loss: 0.5958, Train Acc: 0.68, Test Loss: 0.6990, Test Acc: 0.59, P@10: 0.8000
# Epoch 92/100, Train Loss: 0.5942, Train Acc: 0.68, Test Loss: 0.7005, Test Acc: 0.58, P@10: 0.7000
# Epoch 93/100, Train Loss: 0.5924, Train Acc: 0.68, Test Loss: 0.7027, Test Acc: 0.58, P@10: 0.8000
# Epoch 94/100, Train Loss: 0.5905, Train Acc: 0.69, Test Loss: 0.7043, Test Acc: 0.58, P@10: 0.7000
# Epoch 95/100, Train Loss: 0.5887, Train Acc: 0.69, Test Loss: 0.7061, Test Acc: 0.58, P@10: 0.8000
# Epoch 96/100, Train Loss: 0.5869, Train Acc: 0.69, Test Loss: 0.7082, Test Acc: 0.57, P@10: 0.8000
# Epoch 97/100, Train Loss: 0.5852, Train Acc: 0.69, Test Loss: 0.7102, Test Acc: 0.57, P@10: 0.8000
# Epoch 98/100, Train Loss: 0.5833, Train Acc: 0.69, Test Loss: 0.7119, Test Acc: 0.57, P@10: 0.8000
# Epoch 99/100, Train Loss: 0.5814, Train Acc: 0.70, Test Loss: 0.7142, Test Acc: 0.58, P@10: 0.8000
# Epoch 100/100, Train Loss: 0.5794, Train Acc: 0.70, Test Loss: 0.7159, Test Acc: 0.57, P@10: 0.7000

# %%
torch.save(model, 'model.pth')

# %%
# del model
# del train_loader
# torch.cuda.empty_cache()
